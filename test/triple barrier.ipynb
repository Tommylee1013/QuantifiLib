# %%
from quantifilib.data import YahooFinanceLoader

loader = YahooFinanceLoader()
data = loader.load(
    'SPY',
    start = '2000-01-01',
    interval = '1d',
    auto_adjust = False,
    multi_level_index = False,
    progress = False
)

# %%
data
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2000-01-03   92.142517  145.437500  148.250000  143.875000  148.250000
# 2000-01-04   88.539192  139.750000  144.062500  139.640625  143.531250
# 2000-01-05   88.697586  140.000000  141.531250  137.250000  139.937500
# 2000-01-06   87.272079  137.750000  141.500000  137.750000  139.625000
# 2000-01-07   92.340485  145.750000  145.750000  140.062500  140.312500
# ...                ...         ...         ...         ...         ...
# 2025-07-15  622.140015  622.140015  627.859985  622.059998  627.520020
# 2025-07-16  624.219971  624.219971  624.729980  618.049988  623.739990
# 2025-07-17  628.039978  628.039978  628.400024  624.179993  624.400024
# 2025-07-18  627.580017  627.580017  629.469971  626.460022  629.299988
# 2025-07-21  630.830017  630.830017  631.539978  628.679993  628.770020
#
#               Volume
# Date
# 2000-01-03   8164300
# 2000-01-04   8089800
# 2000-01-05  12177900
# 2000-01-06   6227200
# 2000-01-07   8066500
# ...              ...
# 2025-07-15  74317300
# 2025-07-16  88987500
# 2025-07-17  68885700
# 2025-07-18  65532300
# 2025-07-21  23641241
#
# [6425 rows x 6 columns]

# %%
from quantifilib.strategy.event_driven.triple_barrier import TripleBarrierLabeling

triple_barrier = TripleBarrierLabeling(
    data = data,
    pt_sl = (2, 1),
    min_ret = 0.01,
    vol_lookback = 20
)

# %%
triple_barrier.get_labels()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/1q/pl9tj55n57s9jg28npxw61n80000gn/T/ipykernel_90304/4181115051.py in ?()
# ----> 1 triple_barrier.get_labels()
#
# ~/Desktop/Pycharm/QuantifiLib/quantifilib/strategy/event_driven/triple_barrier.py in ?(self, drop_min_pct)
#     289     def get_labels(self, drop_min_pct : float = None) -> pd.DataFrame:
# --> 290         events = self._get_events(
#     291             t_events = self.close.index[2:]
#     292         )
#     293
#
# ~/Desktop/Pycharm/QuantifiLib/quantifilib/strategy/event_driven/triple_barrier.py in ?(self, t_events)
#     245     def _get_events(self, t_events: pd.Index) -> pd.DataFrame:
#     246         target = self.target.loc[t_events]
#     247         target = target[target > self.min_ret]
#     248
# --> 249         v_barriers = self._add_vertical_barrier(t_events) or pd.Series(pd.NaT, index=t_events)
#     250
#     251         if self.side_prediction is None:
#     252             side_ = pd.Series(1.0, index=target.index)
#
# ~/anaconda3/envs/MLfinance/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
